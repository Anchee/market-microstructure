# %% [markdown]
# # MTH9879 Homework 4
#
# Assigned: February 21, 2017.
# Due: March 7, 2017 by 6pm.
#
# Late homework **will not be accepted**.
#
# $$
# \newcommand{\underbar}{\underline}
# \newcommand{\supp}{\mathrm{supp}}
# \newcommand{\E}{\mathbb{E}}
# \newcommand{\EE}{\mathbb{E}}
# \newcommand{\Eof}[1]{\mathbb{E}\left[ #1 \right]}
# \def\Cov{{ \mbox{Cov} }}
# \def\Var{{ \mbox{Var} }}
# \newcommand{\1}{\mathbf{1} }
# \newcommand{\PP}{\mathbb{P} }
# %\newcommand{\Pr}{\mathrm{Pr} }
# \newcommand{\QQ}{\mathbb{Q} }
# \newcommand{\RR}{\mathbb{R} }
# \newcommand{\DD}{\mathbb{D} }
# \newcommand{\HH}{\mathbb{H} }
# \newcommand{\spn}{\mathrm{span} }
# \newcommand{\cov}{\mathrm{cov} }
# \newcommand{\sgn}{\mathrm{sgn} }
# \newcommand{\HS}{\mathcal{L}_{\mathrm{HS}} }
# %\newcommand{\HS}{\mathrm{HS} }
# \newcommand{\trace}{\mathrm{trace} }
# \newcommand{\LL}{\mathcal{L} }
# %\newcommand{\LL}{\mathrm{L} }
# \newcommand{\s}{\mathcal{S} }
# \newcommand{\ee}{\mathcal{E} }
# \newcommand{\ff}{\mathcal{F} }
# \newcommand{\hh}{\mathcal{H} }
# \newcommand{\bb}{\mathcal{B} }
# \newcommand{\dd}{\mathcal{D} }
# \newcommand{\g}{\mathcal{G} }
# \newcommand{\p}{\partial}
# \newcommand{\half}{\frac{1}{2} }
# \newcommand{\T}{\mathcal{T} }
# \newcommand{\bi}{\begin{itemize}}
# \newcommand{\ei}{\end{itemize}}
# \newcommand{\beq}{\begin{equation}}
# \newcommand{\eeq}{\end{equation}}
# \newcommand{\beas}{\begin{eqnarray*}}
# \newcommand{\eeas}{\end{eqnarray*}}
# \newcommand{\cO}{\mathcal{O}}
# \newcommand{\cF}{\mathcal{F}}
# \newcommand{\cL}{\mathcal{L}}
# \newcommand{\BS}{\text{BS}}
# $$

# %% [markdown]
# <font color = "red">Homework is to be done by each student individually.  To receive full credit, you must email a completed copy of this iPython notebook to Victor Istratov (stavka@gmail.com), Yassine Ghalem (yassine.ghalem@gmail.com) and Jim Gatheral (jim.gatheral@gmail.com) by the due date and time.  All R-code must run correctly and solutions must be written up neatly in Markdown/LaTeX format.

# %% [markdown]
# ### R version 3.3.2 (2016-10-31) (ubuntu)

# %% [markdown]
# ### 0. (0 points)
# Read Chapter 5 and 6 of Hasbrouck and Chapters 2 and 3 of Foucault, Pagano and R&ouml;ell.

# %% [markdown]
# ## Glosten and Milgrom

# %% [markdown]
# ### 1. (8 points)
#
# (Adapted from Hasbrouck 5.2 but please note that the setup in (3) in the slides is different from Hasbrouck's in Figure 5.1 of his book.) Consider a variant of the Glosten and Milgrom model where there is informed trading only in the low state $V=\underline V$.
#
# (a) Show that the learned probability after one step that the true price is $\bar V$ is given by
#
# $$
# \delta_1(Buy)=\Pr(\bar V|Buy)=\frac{\delta}{1-\mu\,(1-\delta)};\quad \delta_1(Sell)=\Pr(\bar V|Sell)=\frac{\delta}{1+\mu\,(1-\delta)}
# $$
#
# and that
#
# $$
# A=\frac{\underline V\,{(1-\delta)\,(1-\mu)}+\bar V\,{\delta}}{{1-\mu\,(1-\delta)}};\quad B=\frac{\underline V\,{(1-\delta)\,(1+\mu)}+\bar V\,{\delta}}{1+\mu\,(1-\delta)}
# $$
#
# (b) Deduce an expression for the spread $s=A-B$.
#
# (c) Explain the sensitivities of the spread to the parameters of the model to a non-expert.

# %% [markdown]
# #### <font color=blue> Solution (a) </font>
#
# The learned probability after one step that the true price is $\bar V$ is:
#
# $$
# \Pr(\bar V|Buy) = \frac{\Pr(\bar V \cap Buy)}{\Pr(Buy)} = \frac{0.5 \delta}{0.5 \delta+0.5(1-\delta)(1-\mu)} = \frac{\delta}{1-\mu\,(1-\delta)}
# \\
# \\
# \Pr(\bar V|Sell) = \frac{\Pr(\bar V \cap Sell)}{\Pr(Sell)} = \frac{0.5 \delta}{0.5 \delta+0.5(1-\delta)(1-\mu)+(1-\delta)\mu} = \frac{\delta}{1+\mu\,(1-\delta)}
# $$
#
# Under perfect competition, the optimal ask price is set as
#
# \begin{eqnarray*}
# A = \mathbb{E} [V|Buy] = \frac{\bar V\,\Pr(\bar V \cap Buy)+\underline V\,\Pr(\underline V \cap Buy)}{\Pr(Buy)} ;\quad
# B=\mathbb{E} [V|Sell] = \frac{\bar V\,\Pr(\bar V \cap Sell)+\underline V\,\Pr(\underline V \cap Sell)}{\Pr(Sell)}
# \end{eqnarray*}
#
# Then
# $$
# A=\frac{\underline V\,{(1-\delta)\,(1-\mu)}+\bar V\,{\delta}}{{1-\mu\,(1-\delta)}};\quad B=\frac{\underline V\,{(1-\delta)\,(1+\mu)}+\bar V\,{\delta}}{1+\mu\,(1-\delta)}
# $$
#
# #### <font color=blue> Solution (b) </font>
#
# $$
# s = A - B = \frac{2 \mu \delta (1 - \delta)(\bar V - \underbar V)}{1 - \mu^2 (1 - \delta)^2}
# $$
#
# #### <font color=blue> Solution (c) </font>
#
# $\mu$:
# The more informed trading is, the wider the spread. Although there is informed trading only in the low state, in such case we may see no dealer willing to post quotes.
#
# $\delta$:
# In the limit where $\delta = 1$ or $\delta = 0$, $s = 0$. So as $\delta$ increases from 0 to 1, the spread must firstly increase and decrease. When the market surely increases or decreases, there will be no spread.
#
#
# $\bar V - \underbar V$:
# When $\bar V - \underbar V$ increases, the spread will increase. Market makers will expand the bid-ask spread to hedge the risk.

# %% [markdown]
# ### Load data and R package for the next questions

# %%
download.file(url="http://mfe.baruch.cuny.edu/wp-content/uploads/2015/02/tq.zip", destfile="tq.zip")
unzip(zipfile="tq.zip")

# %%
load('tq.rData')
library(highfrequency)
library(xts)
library(quantmod)
tqdata <- tqBAC
# Out:
# Loading required package: xts
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: TTR
# Version 0.4-0 included new data defaults. See ?getSymbols.
#
# Attaching package: ‘quantmod’
#
# The following objects are masked from ‘package:highfrequency’:
#
#     getPrice, has.Qty

# %% [markdown]
# ## The Lee and Ready tick test

# %% [markdown]
# ### 2. (10 points)
#
# In the following use the trades and quotes object *tqBAC* in the loaded data *tq.rData*.  Denote trade prices by $p_t$ and mid-quotes by $m_t$.
#
# (a) Compute the time series of trade signs $\epsilon_t$ according to $\epsilon_t=+1$ if $p_t>m_t$ and  $\epsilon_t=-1$ otherwise, using the Lee-Ready rule for trades at mid.  Name this series *tradeSigns*. (Note this was already done in the lecture.)
#
# (b) Compute the Lee-Ready trade-sign indicator time series (as if you didn't have quotes and so no mid-prices).
#
# (c) Compute the correlation of these two indicators.
#
# (d) Assume the rule in part (a) is 100% accurate.  What percentage of trades are correctly signed by the Lee-Ready test?
#
# (e) Explain the relationship between your answers in (c) and (d).

# %% [markdown]
# #### <font color=blue> Solution (a) </font>

# %%
tradeSigns <- getTradeDirection(tqdata)

# %% [markdown]
# #### <font color=blue> Solution (b) </font>
#
# According to the rules:
# - If a trade is on an uptick, it is a buy.
# - If the trade is on a downtick, it is a sell.
# - If the trade is on a zero-uptick, it is a buy.
# - If the trade is on a zero-downtick, it is a sell.

# %%
tq_price <- as.numeric(tqdata$PRICE)
# The first deal is buy by default
LR_tradeSigns <- c(1)
for (i in 2:length(tq_price)){
    if (tq_price[i] > tq_price[i-1])
        LR_tradeSigns = append(LR_tradeSigns,1)
    else if (tq_price[i] < tq_price[i-1])
        LR_tradeSigns = append(LR_tradeSigns,-1)
    else
        LR_tradeSigns = append(LR_tradeSigns,LR_tradeSigns[i-1])
}

# %% [markdown]
# #### <font color=blue> Solution (c) </font>

# %%
cor(tradeSigns,LR_tradeSigns)
# Out:
# [1] 0.661735

# %% [markdown]
# #### <font color=blue> Solution (d) </font>

# %%
length(which((tradeSigns - LR_tradeSigns == 0) == TRUE)) / length(tradeSigns)
# Out:
# [1] 0.8296562

# %% [markdown]
# #### <font color=blue> Solution (e) </font>
#
# The answers to (c) and (d) is consistent since we can see there is a high percentage of trades are correctly signed by Lee-Ready test and the correlation between tradeSigns and LR_tradeSigns is high.

# %% [markdown]
# ## Realized spread by exchange

# %% [markdown]
# ### 3. (8 points)
#
# (a) Reproduce Figure 6 from the lecture slides, making sure to get the aesthetics right.
#
# (b) Explain why the realized spread profile varies by exchange.
#
# (c) Redo the picture adjusting for the following (assumed) take fees:
#
# ** Exchange ** | ** Take fee **
# --- | ---
# | (**cents**)
# D | 0.10
# B | -0.04
# Z | 0.29
# Y | 0.00
# P | 0.25
#
# (d) Based on your results, where would you advise sending a small market order?  How about a large one?

# %% [markdown]
# #### <font color=blue> Solution (a) </font>

# %%
# Realized spread
rs <- function(lag, ex){
    tqdata_ex <- tqdata[tqdata$EX == ex]
    tradesigns <- getTradeDirection(tqdata_ex)
    p <- as.numeric(tqdata_ex$PRICE)
    n <- length(p)
    mids <- (as.numeric(tqdata_ex$OFR) + as.numeric(tqdata_ex$BID))/2
    return (mean(tradesigns[1:(n-lag)]*(p[1:(n-lag)]-mids[-(1:lag)])))
}

#---------------------------------------------------------------------------
options(repr.plot.width=10,repr.plot.height=7)
plot(1:50,sapply(1:50, ex = "D", rs),col="red",type="l",xlab=expression(tau), ylab = "Realized spread",ylim = c(-0.003, 0.007))
lines(1:50,sapply(1:50, ex = "B", rs),col="blue",type="l")
lines(1:50,sapply(1:50, ex = "Z", rs),col="orange",type="l")
lines(1:50,sapply(1:50, ex = "Y", rs),col="purple",type="l")
lines(1:50,sapply(1:50, ex = "P", rs),col="green",type="l")
legend("bottomright", 
       c("D...FINRA", "B...NASDAQ", "Z...BATS Exchange", "Y...BATS Y-Exchange", "P...NYSE"), 
       lty = c(1,1,1,1,1), col=c("red","blue","orange","purple", "green"),cex=0.5)
# Out:
# plot without title

# %% [markdown]
# #### <font color=blue> Solution (b) </font>
# There are three main determinants of the bid-ask spread: Processing costs (which include the profit of the market maker); Inventory costs such as cost of risk capital; Adverse selection.
#
# Exchanges can changes the above three factors, thus changing the spread.

# %% [markdown]
# #### <font color=blue> Solution (c) </font>
# Positive take fees could increase the spread.

# %%
options(repr.plot.width=10,repr.plot.height=7)
plot(1:50,sapply(1:50, ex = "D", rs)+0.001*2,col="red",type="l",xlab=expression(tau), ylab = "Realized spread",ylim = c(-0.003, 0.012))
lines(1:50,sapply(1:50, ex = "B", rs)-0.0004*2,col="blue",type="l")
lines(1:50,sapply(1:50, ex = "Z", rs)+0.0029*2,col="orange",type="l")
lines(1:50,sapply(1:50, ex = "Y", rs),col="purple",type="l")
lines(1:50,sapply(1:50, ex = "P", rs)+0.0025*2,col="green",type="l")
legend("bottomright", 
       c("D...FINRA", "B...NASDAQ", "Z...BATS Exchange", "Y...BATS Y-Exchange", "P...NYSE"), 
       lty = c(1,1,1,1,1), col=c("red","blue","orange","purple", "green"),cex=0.5)
# Out:
# plot without title

# %% [markdown]
# #### <font color=blue> Solution (d) </font>
#
# The key is the tradeoff between liquidity and fee. When the take fee is negative the liquidity is large, and thus we should choose exchange B for the small amount market order.

# %% [markdown]
# ## Predicting trade signs

# %% [markdown]
# ### 4. (6 points)
#
# The following require the *tradeSigns* series from Problem 2.
#
# (a) Denote the probability of a sign reversal by $\pi$.  Derive an expression in terms of $\pi$ for the conditional expectation $\E[\epsilon_t|\epsilon_{t-1}]$.
#
# (b) Assume zero expectation of the trading signs, fit an AR(1) model to the series *tradeSigns*.  What is the coefficient returned by this model?  Explain how  this coefficient relates to $\pi$?

# %% [markdown]
# #### <font color=blue> Solution (a) </font>
# From the definition of expection,
# $$
# \E[\epsilon_t|\epsilon_{t-1}] = \pi(- \epsilon_{t-1}) + (1 - \pi) \epsilon_{t-1} = \epsilon_{t-1}(1-2\pi)
# $$

# %% [markdown]
# #### <font color=blue> Solution (b) </font>

# %%
epsilon_t = tradeSigns[1:(length(tradeSigns)-1)]
epsilon_t_1 = tradeSigns[2:length(tradeSigns)]
# no constant since we assume zero expectation of the trading signs
ar1 <- lm(epsilon_t ~ 0+ epsilon_t_1)
rho <- coefficients(ar1)
cat("The coefficient is", rho)
# Out:
# The coefficient is 0.08472868

# %% [markdown]
# How this coefficient relates to $\pi$:
#
# We have
# $$
# \epsilon_t=\rho\epsilon_{t-1}+\eta_t
# $$
# Then,
# $$
# \E[\epsilon_t|\epsilon_{t-1}]=\rho\epsilon_{t-1}
# $$
# Thus,
# $$
# \rho\approx (1-2\pi)
# $$

# %% [markdown]
# ## The MRR model

# %% [markdown]
# ### 5. (6 points)
# Using the estimate of $\rho$ (the coefficient obtained from fitting to an AR(1) model) from Problem 4 and equation (11) from the lecture slides:
#
# $$
# \Delta p_t=(\phi+\lambda)\,\epsilon_t-(\phi+\rho\,\lambda)\,\epsilon_{t-1}+e_t+\Delta \xi_t
# $$
#
# estimate by linear regression the MRR parameters $\phi$ (transaction cost) and $\lambda$ (adverse selection or "Kyle lambda") from  *tqBAC*.  This amounts to ignoring the autocorrelation of the $\Delta \xi_t$.
# <br>
#
# Hint: Use the R function *lm*  to perform the linear regressions.

# %% [markdown]
# #### <font color=blue> Solution </font>

# %%
p <- as.numeric(tqdata$PRICE)
dp <- diff(p)
mrr <- lm(dp ~ epsilon_t + epsilon_t_1)
coeffs <- coefficients(mrr)
cat("The first term coefficient is:", coeffs[2])
cat("\nThe second term coefficient is:", coeffs[3])
# Out:
# The first term coefficient is: -0.002336749
# The second term coefficient is: 0.002876938

# %% [markdown]
# So we get
# $$
# \phi+\lambda=-0.002336749,\\
# -(\phi+\rho\lambda)=0.002876938
# $$
# Then
# $$
# \phi=-0.00292489, \lambda=0.00058814
# $$
